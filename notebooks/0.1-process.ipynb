# %% [markdown]
# ### Imports

# %%
import re
from detoxify import Detoxify
import pandas as pd
import numpy as np
from typing import List
import hackathon_somos_nlp_2023.data.load as load
from pigeon import annotate

# %% [markdown]
# ### Load data

# %%
data_raw = load.data_raw
data_processed = load.data_processed

# %% [markdown]
# ### Read data

# %%
# Read 'csv' file as dataframe
df = pd.read_csv(f'{data_raw}/sample.csv')

# Show dataframe
df.head(5)
# Out:
#                     id      conversation_id  referenced_tweets.replied_to.id  \
# 0  1641555769178079232  1641555769178079232                              NaN
# 1  1641555769202974726  1641555769202974726                              NaN
# 2  1641555769194692619  1641503325123235841                     1.641544e+18
# 3  1641555769186471936  1641555769186471936                              NaN
# 4  1641555769194844161  1641555769194844161                              NaN
#
#    referenced_tweets.retweeted.id  referenced_tweets.quoted.id  \
# 0                             NaN                          NaN
# 1                    1.640384e+18                          NaN
# 2                             NaN                          NaN
# 3                    1.641526e+18                          NaN
# 4                             NaN                          NaN
#
#              author_id  in_reply_to_user_id in_reply_to_username  \
# 0  1590296247055060992                  NaN                  NaN
# 1  1486710311109337097                  NaN                  NaN
# 2  1576752300097421312         7.754652e+17       carbolover1967
# 3  1623575319637594113                  NaN                  NaN
# 4  1592728927344025600                  NaN                  NaN
#
#    retweeted_user_id retweeted_username  ...  geo.geo.bbox geo.geo.type  \
# 0                NaN                NaN  ...           NaN          NaN
# 1       1.343320e+18      lycanthropexx  ...           NaN          NaN
# 2                NaN                NaN  ...           NaN          NaN
# 3       1.574030e+18         suzuren921  ...           NaN          NaN
# 4                NaN                NaN  ...           NaN          NaN
#
#   geo.id geo.name geo.place_id  geo.place_type  matching_rules  \
# 0    NaN      NaN          NaN             NaN             NaN
# 1    NaN      NaN          NaN             NaN             NaN
# 2    NaN      NaN          NaN             NaN             NaN
# 3    NaN      NaN          NaN             NaN             NaN
# 4    NaN      NaN          NaN             NaN             NaN
#
#         __twarc.retrieved_at  \
# 0  2023-03-30T21:39:34+00:00
# 1  2023-03-30T21:39:34+00:00
# 2  2023-03-30T21:39:34+00:00
# 3  2023-03-30T21:39:34+00:00
# 4  2023-03-30T21:39:34+00:00
#
#                                          __twarc.url  __twarc.version
# 0  https://api.twitter.com/2/tweets/sample/stream...           2.13.0
# 1  https://api.twitter.com/2/tweets/sample/stream...           2.13.0
# 2  https://api.twitter.com/2/tweets/sample/stream...           2.13.0
# 3  https://api.twitter.com/2/tweets/sample/stream...           2.13.0
# 4  https://api.twitter.com/2/tweets/sample/stream...           2.13.0
#
# [5 rows x 83 columns]

# %%
# Filter data
df_es = df.loc[df['lang'] == 'es'].reset_index(drop=True)

# Show dataframe
df_es.head(5)
# Out:
#                     id      conversation_id  referenced_tweets.replied_to.id  \
# 0  1641555769194692619  1641503325123235841                     1.641544e+18
# 1  1641555769186295811  1641555054770507778                     1.641555e+18
# 2  1641555769198891008  1641555769198891008                              NaN
# 3  1641555769198796802  1641555769198796802                              NaN
# 4  1641555773397381121  1641555773397381121                              NaN
#
#    referenced_tweets.retweeted.id  referenced_tweets.quoted.id  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                    1.641446e+18                          NaN
# 3                             NaN                          NaN
# 4                    1.641522e+18                          NaN
#
#              author_id  in_reply_to_user_id in_reply_to_username  \
# 0  1576752300097421312         7.754652e+17       carbolover1967
# 1  1498794390378070017         1.433880e+18         koicarpincho
# 2  1633549880256757760                  NaN                  NaN
# 3  1293944610180468742                  NaN                  NaN
# 4  1507231284216549379                  NaN                  NaN
#
#    retweeted_user_id retweeted_username  ...  geo.geo.bbox geo.geo.type  \
# 0                NaN                NaN  ...           NaN          NaN
# 1                NaN                NaN  ...           NaN          NaN
# 2       1.485945e+18          flemitang  ...           NaN          NaN
# 3                NaN                NaN  ...           NaN          NaN
# 4       1.018220e+08    rochaperiodista  ...           NaN          NaN
#
#   geo.id geo.name geo.place_id  geo.place_type  matching_rules  \
# 0    NaN      NaN          NaN             NaN             NaN
# 1    NaN      NaN          NaN             NaN             NaN
# 2    NaN      NaN          NaN             NaN             NaN
# 3    NaN      NaN          NaN             NaN             NaN
# 4    NaN      NaN          NaN             NaN             NaN
#
#         __twarc.retrieved_at  \
# 0  2023-03-30T21:39:34+00:00
# 1  2023-03-30T21:39:34+00:00
# 2  2023-03-30T21:39:34+00:00
# 3  2023-03-30T21:39:34+00:00
# 4  2023-03-30T21:39:35+00:00
#
#                                          __twarc.url  __twarc.version
# 0  https://api.twitter.com/2/tweets/sample/stream...           2.13.0
# 1  https://api.twitter.com/2/tweets/sample/stream...           2.13.0
# 2  https://api.twitter.com/2/tweets/sample/stream...           2.13.0
# 3  https://api.twitter.com/2/tweets/sample/stream...           2.13.0
# 4  https://api.twitter.com/2/tweets/sample/stream...           2.13.0
#
# [5 rows x 83 columns]

# %% [markdown]
# ### Process data

# %%
labels = []
def label_data(data: List) -> List:
    for x in data:
        labels.append(Detoxify('multilingual'.predict(x)))
    return labels

# %%
# Clean text
df_es['text'] = df_es['text'].apply(lambda x: re.sub(r'\\u[0-9A-Fa-f]+|\\n', '', x))

# Convert column values to list
texts = df_es['text'].to_list()

# %%
results = Detoxify('multilingual').predict(texts)

# %%
# Convert dict to dataframe
df_results = pd.DataFrame.from_dict(results)

# Round floats
df_results = df_results.round(2)

# Add new column
df_results['text'] = df_es['text']

# Show dataframe
df_results
# Out:
#      toxicity  severe_toxicity  obscene  identity_attack  insult  threat  \
# 0        0.00              0.0     0.00              0.0    0.00     0.0
# 1        0.12              0.0     0.02              0.0    0.02     0.0
# 2        0.67              0.0     0.06              0.0    0.50     0.0
# 3        0.01              0.0     0.00              0.0    0.00     0.0
# 4        0.01              0.0     0.00              0.0    0.00     0.0
# ..        ...              ...      ...              ...     ...     ...
# 633      0.00              0.0     0.00              0.0    0.00     0.0
# 634      0.00              0.0     0.00              0.0    0.00     0.0
# 635      0.00              0.0     0.00              0.0    0.00     0.0
# 636      0.00              0.0     0.00              0.0    0.00     0.0
# 637      0.01              0.0     0.01              0.0    0.01     0.0
#
#      sexual_explicit                                               text
# 0                0.0                  @carbolover1967 @Agusitooh Domado
# 1                0.0  @koicarpincho es lo más rico q hay dios Y LA M...
# 2                0.0  @shitpostingMP4 nunca lo banque, nose q le veí...
# 3                0.0  Mk que frustrada me siento, a veces dar el 100...
# 4                0.0  El INE obedeciendo a la queja de la senadora d...
# ..               ...                                                ...
# 633              0.0  Escrivá quiere que los autónomos aporten el 40...
# 634              0.0  Esta un poquito grueso pero te va hacerla bien...
# 635              0.0  @prospericarlos @hramosallup @PieroMaroun @con...
# 636              0.0  Que se vaya cuanto antes! #SVGala5 https://t.c...
# 637              0.0      Lol penaaal?? No lo veo tan claro pero daleee
#
# [638 rows x 8 columns]

# %%
# Create a new column
df_results['label'] = df_results['toxicity'].apply(lambda x: 0 if round(x) < 0.3 else 1)

# Show dataframe
df_results.head(5)
# Out:
#    toxicity  severe_toxicity  obscene  identity_attack  insult  threat  \
# 0      0.00              0.0     0.00              0.0    0.00     0.0
# 1      0.12              0.0     0.02              0.0    0.02     0.0
# 2      0.67              0.0     0.06              0.0    0.50     0.0
# 3      0.01              0.0     0.00              0.0    0.00     0.0
# 4      0.01              0.0     0.00              0.0    0.00     0.0
#
#    sexual_explicit                                               text  label
# 0              0.0                  @carbolover1967 @Agusitooh Domado      0
# 1              0.0  @koicarpincho es lo más rico q hay dios Y LA M...      0
# 2              0.0  @shitpostingMP4 nunca lo banque, nose q le veí...      1
# 3              0.0  Mk que frustrada me siento, a veces dar el 100...      0
# 4              0.0  El INE obedeciendo a la queja de la senadora d...      0

# %%
# Filter data
df_negative = df_results.loc[df_results['label'] == 0]

# Show dataframe
df_negative
# Out:
#      toxicity  severe_toxicity  obscene  identity_attack  insult  threat  \
# 0        0.00              0.0     0.00              0.0    0.00     0.0
# 1        0.12              0.0     0.02              0.0    0.02     0.0
# 3        0.01              0.0     0.00              0.0    0.00     0.0
# 4        0.01              0.0     0.00              0.0    0.00     0.0
# 6        0.00              0.0     0.00              0.0    0.00     0.0
# ..        ...              ...      ...              ...     ...     ...
# 633      0.00              0.0     0.00              0.0    0.00     0.0
# 634      0.00              0.0     0.00              0.0    0.00     0.0
# 635      0.00              0.0     0.00              0.0    0.00     0.0
# 636      0.00              0.0     0.00              0.0    0.00     0.0
# 637      0.01              0.0     0.01              0.0    0.01     0.0
#
#      sexual_explicit                                               text  label
# 0                0.0                  @carbolover1967 @Agusitooh Domado      0
# 1                0.0  @koicarpincho es lo más rico q hay dios Y LA M...      0
# 3                0.0  Mk que frustrada me siento, a veces dar el 100...      0
# 4                0.0  El INE obedeciendo a la queja de la senadora d...      0
# 6                0.0  "Qué bonita la naturaleza, cuánto hemos de apr...      0
# ..               ...                                                ...    ...
# 633              0.0  Escrivá quiere que los autónomos aporten el 40...      0
# 634              0.0  Esta un poquito grueso pero te va hacerla bien...      0
# 635              0.0  @prospericarlos @hramosallup @PieroMaroun @con...      0
# 636              0.0  Que se vaya cuanto antes! #SVGala5 https://t.c...      0
# 637              0.0      Lol penaaal?? No lo veo tan claro pero daleee      0
#
# [599 rows x 9 columns]

# %%
# Remove rows with less than 3 words in 'text' column 
df_tokens = df_negative.loc[df['text'].str.count(" ") >= 3]

# Filter dataframe
df_final = df_tokens[['text', 'label']]

list_text = df_final['text'].to_list()

# Show dataframe
df_final
# Out:
#                                                   text  label
# 1    @koicarpincho es lo más rico q hay dios Y LA M...      0
# 4    El INE obedeciendo a la queja de la senadora d...      0
# 6    "Qué bonita la naturaleza, cuánto hemos de apr...      0
# 7    Y pensar que Carabineros tiene que lidiar con ...      0
# 8    @gort_lucy George harris  dice lo mismo con un...      0
# ..                                                 ...    ...
# 630  -Hay que votar Milei lista completa.-y quien v...      0
# 634  Esta un poquito grueso pero te va hacerla bien...      0
# 635  @prospericarlos @hramosallup @PieroMaroun @con...      0
# 636  Que se vaya cuanto antes! #SVGala5 https://t.c...      0
# 637      Lol penaaal?? No lo veo tan claro pero daleee      0
#
# [482 rows x 2 columns]

# %%
annotations = annotate(list_text, options=['positivo', 'negativo'])
# Out:
# HTML(value='0 examples annotated, 483 examples left')
# HBox(children=(Button(description='positivo', style=ButtonStyle()), Button(description='negativo', style=Butto…
# Output()
# Annotation done.

# %%
df_final['annotations'] = list(map(lambda x: x[1], annotations))

df_final
# Out:
# /tmp/ipykernel_74487/1181650446.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['annotations'] = list(map(lambda x: x[1], annotations))
#                                                   text  label annotations
# 1    @koicarpincho es lo más rico q hay dios Y LA M...      0    negativo
# 4    El INE obedeciendo a la queja de la senadora d...      0    positivo
# 6    "Qué bonita la naturaleza, cuánto hemos de apr...      0    negativo
# 7    Y pensar que Carabineros tiene que lidiar con ...      0    positivo
# 8    @gort_lucy George harris  dice lo mismo con un...      0    positivo
# ..                                                 ...    ...         ...
# 630  -Hay que votar Milei lista completa.-y quien v...      0    positivo
# 634  Esta un poquito grueso pero te va hacerla bien...      0    positivo
# 635  @prospericarlos @hramosallup @PieroMaroun @con...      0    positivo
# 636  Que se vaya cuanto antes! #SVGala5 https://t.c...      0    negativo
# 637      Lol penaaal?? No lo veo tan claro pero daleee      0    positivo
#
# [482 rows x 3 columns]

# %%
# Add column for label
conditions = [
    (df_final['annotations'] == "positivo"),
    (df_final['annotations'] == "negativo"),
    ]

values=[1,0]

df_final['new_label']=np.select(conditions,values)
# Out:
# /tmp/ipykernel_74487/1642658833.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['new_label']=np.select(conditions,values)

# %%
df_final = df_final.loc[df_final['new_label'] == 0]

df_final = df_final[['text', 'label']]

df_final
# Out:
#                                                   text  label
# 1    @koicarpincho es lo más rico q hay dios Y LA M...      0
# 6    "Qué bonita la naturaleza, cuánto hemos de apr...      0
# 12   el dolorcito en el pecho cuando ves algo que n...      0
# 13   @arturocazal Sea lo que sea hay que recuperar ...      0
# 14   cómo odio matemática hace una hora con el mism...      0
# ..                                                 ...    ...
# 620              Nominación directa para Alma #SVGala5      0
# 621  Antes de emitir un Juicio sobre el Mechero, pi...      0
# 624  Dónde me cuidan yo cuido el triple, y dónde me...      0
# 627    Les gusta mi corazón?🙈💗 https://t.co/vZrpiqHtbc      0
# 636  Que se vaya cuanto antes! #SVGala5 https://t.c...      0
#
# [263 rows x 2 columns]

# %%
# Clean text
df_final['text'] = df_final['text'].apply(lambda x: re.sub(r'\\u[0-9A-Fa-f]+', '', x))

text_clean = df_final['text'].to_list()

text_clean
# Out:
#  'Jajshfjajaj a veces cito cosas desde mi cuenta privada jajajdh me siento en el google incógnito https://t.co/19iRl9VdM2',
#  'Yo paso de toda esa gente, me fuuuuuuiiiiiiii 🚶\u200d♀️',
#  'neta me siento insoportable',
#  'Ahora si ya me completo el día',
#  '@Abellcymeg No lo dicen por ella, sino porque las Producciones de DW no bajan su calidad sin importar que tan nuevos sean, cosa que Disney no hace.',
#  '@todonoticias Y bajense hermano si no estan aptos! Dejen de vaciar el estado y poner excusas se necesitan gente con huevos ahi que agarre el toro por las astas ustedes son una lagrima siempre llorando y justificando la pobreza por culpa del que estuvo antes',
#  'Vivo en un constante https://t.co/ValkvWm7IU',
#  '@ppciclon ahora van a poder jugar de noche, creo…',
#  '@CamaleonaFeliz A bueno yo quiero :D',
#  'si ninguno es el tuyo, no quiero nada https://t.co/RL3KyeW0Os',
#  '@WestCOL_ Eso es todo!! https://t.co/EQ27I9RbTp',
#  '💜 Crea una vida que ames 💜#deinnotservice #deinnotservices #deinnots #deinnot #amorpropio #amor #amore #amor❤ #diseñodigital #diseñador #disenografico #diseño #diseñografico #diseno #diseñocolombiano #diseños #innovation #innovacion #technologie #technology #tecnology https://t.co/oCzcp2rZxR',
#  'no estamos hechos el uno para el otro',
#  '... tendré que ser más dura https://t.co/ZZOx7A6kA9',
#  '@UnidosPoniente No es justo que encierren a los líderes sociales que ayuden a las personas sin condiciones. Gracias Lennin por tus apoyos.',
#  'mañana no va a ser lo mismo sin ti 🙁',
#  '@latercera Después rechazo salga lo que salga',
#  'querer ser productivo 🤝 querer dormir',
#  'amo cómo me cuidan mis amigos y mi familia \U0001f979 aunque no quiero preocuparlos, es lindo saber que alguien te cuida, se preocupa por ti y te quiere ❤️\u200d🩹 losamooooooooo ayyy',
#  'amigos tiktokers a q le hago caso? yo nomas quería subir bits cawn 😪 https://t.co/vQeYZbU4a8',
#  'LO QIERO MUCHO https://t.co/FB8ma4gkWW',
#  'Me puse a pintar el depa con Pecos Kanvas de fondo, qué tal?',
#  'Revela la Secretaría de Seguridad la lista de los 39 muertos por el terrible incendio en estación migratoria de Ciudad Juárez, Chihuahua. Contabilizan seis hondureños, siete salvadoreños, 18 guatemaltecos, un colombiano y siete venezolanos https://t.co/yupzwOq8J0 https://t.co/YN8wFB4Juf',
#  '@vivicanosaok Igual que vos! Feliz cumple mujer valiente 🥂 https://t.co/RNxTNt0pM1',
#  'La pregunta es...¿Nos da tiempo llegar a clase?──── En aquel momento, aceptar una proposición tan inocente, no le parecía tan mala idea.──── https://t.co/Cu9wXKjSTf',
#  'Ya salí de trabajar, estoy yendo derechito a acostarme con el mate y sándwich de miga. Me dedico altos planes',
#  'Incluyendolo a usted https://t.co/7HN9rpqa9H',
#  '“los juegos de mesa son para relajarse” https://t.co/EtwNEAiKVM',
#  'necesito amigos para salir',
#  '@rosyserna @YoZhoy Tiene razón,La juventud es pasajera y hay que disfrutarla.',
#  '¡Mis oficinas esta semana!País Vasco y Cantabria¡Increíble! https://t.co/Qi7ISkj5ZN',
#  'por dios limpiaros las orejas',
#  'Ah bueno, entonces no es tan grave. Menos mal. https://t.co/pEYFVStOwh',
#  'No lo quiero, LO NECESITO https://t.co/Ia4aylVJK6',
#  'Me llegó un correo sobre el proyecto y me ilusionó, pensé que lo habían aprobado lpm por qué hacen estooo',
#  'Se los dije: no voy a acompañar ningún acuerdo que no incluya las renuncias de @adan_augusto, @A_Encinas_R y @fgymexico. No me prestaré a lavarle la cara a los responsables del Crimen de Estado ocurrido en Cd. Juárez. Que los proteja y solape su jefe. Yo no. Por eso no voté. https://t.co/8w1iShUPav',
#  '@Euraje1 @MrDryES pero si el evento de Xbox va a suceder en las mismas fechas planeadas XD y luego .... 2022??',
#  '@ernestormj @lubrio @OOsteicoechea @soyescalavzla @CPerdomo28 @CarlosLoret @AlexaGomezDos Pero cual es el miedo que muestre los videos? Jajajaja los nuevos emprendimientos.',
#  '@wardsergiook @RadioHisteriaOK @lalioficial Todavía no salió pero cuando salga el disco fisico calculo q se va a comprar en librerías y diquerias',
#  'Oigan, ¿Por qué la @FLIP_org no se ha pronunciado respecto a esto? ¿Libertad de prensa para unos sí y para otros no? ¿Un Congresista atacando de esta manera a un medio de comunicación y no se inmutan en decir nada? https://t.co/oBelXo4Sr2',
#  'jueves de heladito con Santi &gt;&gt;&gt;&gt; 💗🥥✨',
#  '@valentiina8_ si esas cosas pasan en valencia, no quiero imaginar en una aldea como la tuya',
#  '@pedro_casares @sanchezcastejon @PSOE @gpscongreso Igual que te encuentras esto seguro que te encuentras otras cosas que no tienes c....., narices de poner',
#  '¿Ya Maduro alzó su voz contra el crimen de Ciudad Juárez donde había 13 venezolanos? No ¿verdad? Ni siquiera un reclamo de justicia, ni un lamento. Está más preocupado por el desmadre interno que lo dejó en ridículo ante los americanos y lo obligó a botar a Tareck El Aissami.',
#  'Lo vemos todos los días en la calle y aún así ver estos números duele. Un millón de nuevos pobres y el Gobierno sigue sin hacer nada. https://t.co/lA2gMGTCVP',
#  '@CAPUFE Caseta de cobro tepatitlan jalisco',
#  '@Tel__TV @SandraGolpeA3TV Qué afortunado. ¡Me alegro! 👏🏻😊',
#  '@valenti27991863 Si algún día quieres responder algún mensaje que te mando…',
#  '@dattisanta no sabe a nada!!',
#  'Si de verdad quisieran @sumar sin destrozar Podemos ya estarían firmando ir juntos en Madrid... Ah no, que ahí los de @MasMadrid__ no quieren @sumar  ni tampoco pedirle a su candidata que dimita por llevarse ayudas a vulnerables. 🤨 #YOVOTOPODEMOS https://t.co/yaoKYVIvwK',
#  '@AbogadosCrist Yo pongo el mechero.',
#  'Nuevos casos de viruela símica. https://t.co/zaqO4jFFuB',
#  '@GabrielBoric No puede haber más atribuciones a Carabineros si no hay reforma a la constitución!!! Basta de darse vuelta. Póngase los pantalones!!! https://t.co/KUfSUGoXjF',
#  'Así de simple, así se grave ... #LeyGatilloFacil #LeyNaimRetamal https://t.co/ChdqiG9rvl',
#  '@74carlosnob @BonelliOK @nilounonilootr1 Jajaj se siguen creyendo el relato realmente viven en su propia irrealidad así estamos país devastado 😩',
#  '@LauraAriastv No hay derecho a esto',
#  'El Lyon con sus 30 fichas cambiando a jugadoras tranquilamente',
#  '@anddort Y si jajajaja como yo no pasaría un examen de estructura quien sabe que con 8 o 7, como ellos no pasarían un examen de Micologia o Parasitologia con 6, hace falta cabecita:)',
#  '@merono_diez @YoungDragon69 Ok.  Gracias.¿No sé quién es el de la derecha?',
#  '¿QUÉ HAY QUE CAMBIAR?¿LA POLíTICA PÚBLICA CREADA POR EL PROPIO @EfrainAlegre ?Coherencia señor, coherencia SEÑORA. https://t.co/lKrSf8uKmV',
#  '@sergiobarbosach @petrogustavo Tambien somos "Criticos", pero con sueldo y como diga lo que piensa le hacen un Alejandro Gaviria...',
#  '@AlexaM77 @alejaaandra Necesito una suegra así 🤣🤣',
#  'Ya casi viernes, con ganas d portarnos mal.... https://t.co/2gRBrD8mSS',
#  'No aguanto no aguanto!!!Aguanta... aguanta!.No podía aguantar, me era muy difícil, creame.No sabía que hacer... ute vealo.😈🔥 https://t.co/sjsLM5ll7d',
#  'Almeida ha arrasado con el 20% de los árboles en mejor estado de Madrid.Este pobre estaba en Arturo Soria. https://t.co/WqYFPNpIT7',
#  'PARECE QUE SON CHUSTES MAL CONTADOS PERO NO #EsClaudia LA ESTÁ DESTRUYENDO LA CIUDAD ..#MorenaElCartelInmobiliario #LigaDeGuerreros https://t.co/QM1ozu6uWC',
#  'lo triste q me pone q dependan de sus psicólogas para cualquier cosa al final pagan para que las terminen de maternar https://t.co/yS2Wx5MH5v',
#  'no existe nada mas puro que intentar sanar heridas que tu no creaste 💚',
#  '@valssaf Se ve bien mijita, no se fije no se fije',
#  'que luche porque no existan intelectuales y eruditos, pues todo lo que pretende podría quedar en mito.@ppopular @NunezFeijoo',
#  'No hago terapia, pero tengo a Gabi \U0001faf6',
#  'En los estados de wpp soy una abuela, en tw una traumada y en ig me hago la linda.',
#  '@bostero_viejo No sé, nadie se muestra. A esa altura, a Guillermo Moreno, que es el único que presentó un plan económico de gobierno.',
#  '@Mileinnials Entre esos Ezeiza',
#  '@maaarriooo Deja de haserte el duro x la reds todos sabemos q luego eres un tierno',
#  'corcho debe permitir la importación de medicinas o miles van a morir.! https://t.co/gqVIzRQePQ',
#  'SIGANME EN IG😣https://t.co/5nBiGu2LB7',
#  'si alguno salta va a saltar mi bandeja(? que dice',
#  'Llegó el día muchachos estoy viendo la Sub 17 teniendo 18, siento dolor, me siento un hombre mayor. Si ya me siento mal con la Sub 17 imagínate cuando me pase con la Sub 20.',
#  'Descarrilamiento del metro en CDMX. A diferencia de otras veces dónde criticamos a @Claudiashein, en esta ocasión voy a colaborar con la investigación.Ha analizado el accidente desde todos sus ángulos y gracias a mi ojo entrenado, detecté el origen del sabotaje. https://t.co/nvMX2IGmQg',
#  '@LaPosta_Ecu @VillaFernando_ Ya no me gusta la Posta ni un poquito',
#  'El machismo es pensar que una mujer no puede conseguir algo por sí sola y darle ayudas o reservar cupos exclusivos para mujeres como hace la izquierda.@vox_es piensa que todos los españoles son iguales sin distinción por sexo.¡Los medios mienten! #ConoceVOX https://t.co/xvW0ft5Slu',
#  'Encima le pone una canción de Rodrigo, siempre me gustaron los del interior 👄 https://t.co/F1DtgwUlJN',
#  'Colombia en el corazón 🇨🇴 #elparce #chile #man #happy #buñuelo https://t.co/BHElkvohWY',
#  'Me JURÉ a mi misma no volver a permitirme llegar a el punto de q una persona tenga el poder de drenarme tanto y tener que estrellarme 528 veces para poder entender',
#  'No se le puede dar impunidad previa a nadie para que pase por encima de los derechos humanos. Espero que el parlamento no caiga en ese error.',
#  'ojalá todo doliera menos',
#  'selena gomez y rosy mcmichael omg las amo tantooooo https://t.co/VMyqKr8vZ3',
#  '@Florrencita @soldesoles5006 @GHargentina_22 @elprimo_MG ¿Estás bien vos amiga? https://t.co/UzcjaESrNe',
#  '@Rey_Reich @crismuiln @FrenteDeTodos Condena firme par todos',
#  'Los pobres de Alberto y Cristina Lamentable !Ah pero Macri. https://t.co/TipvSJsdRP',
#  'No Es Miedo a Enamorarme sino Miedo a que tu no sientas Lo mismo por mi! :s',
#  '¿Estáis de acuerdo con estas medidas de VOX? https://t.co/Iwd8rbkSc8',
#  '@softneoboyz madre mía qué caos',
#  '@usuario_del_sur A nada de sacarme la  🦋 del user YO LA MENOS DRAMATICA',
#  '@lfayala2272 La carrera que estoy estudiando, la forma en la que administro mis ahorros, etc.',
#  '@PedroKonductaz @jguaido Primero estarías tu.',
#  'A seguir difundiendo, Camaradas, este delincuente no debe quedar IMPUNE! https://t.co/5mSxtxwhNw',
#  'No nos damos cuenta de lo mal que vivimos hasta que alguien que está afuera nos hace acordar. https://t.co/1dBH9n3ZzA',
#  'Que BÁRBARO, me informan que en los tribunales de Valencia, Maracay y Caracas se han SUSPENDIDO un coñazo de audiencias por que los Jueces, Fiscales y parte del personal administrativo HUYÓ, están escondidos, con los teléfonos apagados y nadie sabe de ellos',
#  'Ningún centro de estudiantes expresa repudio a la humillante regulada de buses de transporte? De la FEUNA ni hablemos por q no cuestiona a las autoridades, es desesperante, los empresarios del transporte hacen lo que quieren y tienen ganancias siderales, faltan obras urgentes! https://t.co/0IJjrISg2y',
#  'La respuesta legal está en el art. 944 del Código Civil. https://t.co/3S02IW74uj https://t.co/gJ7mI4Ti4L',
#  '@DulcepersonaR No, no todas las comunidades lo tienen y ahí está el punto, en el conflicto de ese reconocimiento con la propiedad privada (o pública). Quitarles el derecho de erigirse como pueblo originario es sacarlos de ese reclamo.',
#  'Adán Chávez,esto es dignidad algo usted desconoce. https://t.co/otvHDEtK8U',
#  'yo namas quiero cejas bonitas y ya',
#  'Viene la época de comer esto en el solcito https://t.co/h4hL3PIi1X',
#  'para mi esto es love language https://t.co/a7P3xOGHC9',
#  'Hoy en día, es común escuchar de metaverso y web3: dos tendencias tecnológicas que constantemente evolucionan. 😲🦾 ¿Alguna vez has escuchado de los riesgos que conllevan? En este #blog de #ManageEngine aprenderás todo acerca de estos dos conceptos. 📚🔗 https://t.co/VuLhwjXlIb https://t.co/MoHL6ZNWz8',
#  '😱 Me sorprende la cantidad de noticias raras que estoy viendo hoy. https://t.co/hXeuuZLAiW',
#  '@Comunero19 @RubenHood15M Zaplana por lo menos estuvo en prisión. Griñán ni 1 día.',
#  '@brenditech Ay tira liiink jaja',
#  '@E_O_C_ Me parece mejor la 1, pero ambas están muy chulas.',
#  '@scatterheartt somos el emoji de facebook de "me enoja" dkdk',
#  'Persona que se consiguió mis 5$... Espero que les haya salvado para algo que necesitara \U0001f972',
#  'En las peores conocemos a los mejores',
#  '@AmeAloMex Creo que sobre valoras al moreno, no es bueno y no genera confianza, no lo victimicen, no es culpa de los dueños ni de los equipos',
#  'yo realmente daría mi vida por ella https://t.co/KqB0OQEvMR',
#  'Gregory Soto vino a sacar un out para culminar el inning, y no ha podido hacerlo. Bases llenas.',
#  'Me siento en uno de esos capítulos de alguna serie policial en donde el detective está de vacaciones y cree que algo raro está pasando y la mujer le dice que es una boludez, q descanse y no se meta e igual lo hace y termina desenmascarando un misterio súper turbio del pueblo.',
#  'Siempre he comparecido a los procesos incluso con el infame montaje de homicidios por 20 años y del que fui declarado inocente. Jamás he huido de la justicia porque mi inocencia es bandera en esta persecución de los clanes mafiosos de la política. En el último año la… https://t.co/Lpp6XArnRV',
#  'Hacemos responsables al PCC de lo que pueda pasar con angel Jesús Veliz Marcano https://t.co/kwIWXecWOc',
#  '@antoreynos0 Y YO SOLA, ES REAL',
#  '@OutOfContexPgod caso de la vida real🙊',
#  'Y estás ganas de marcharme el cabello?',
#  '@CronicaTV Qué cosa tan curiosa,  no trascendió el nombre del "empresario".',
#  '@valerietoala_ JAJAJAJAJA ya respondí toditos🥺',
#  '@Yuliana_5517 Déjame que ando muy feliz:(',
#  '“La compasión, la comunidad y la humanidad están entrelazadas en el sentido de que ejemplifican la expresión completa de quiénes somos como humanos.”— Paul Conti',
#  '@pilareyre Tú te lees? Deja de decir sandeces, anda.',
#  'La supuesta honestidad es la base, pero también se extiende la creencia que sus actos son para los pobres y que todo lo que se dice contra él es y será falso.15/21 https://t.co/8HUEmvW5kn',
#  'Pues alchile q bueno q eligieron a Águila para ROTB y no a Ratatrampa, huviera sido un error q aparezca sin Dinobot https://t.co/ZznLerhnyA',
#  "@_JONAN_ Van a ser sbc's muy del estilo",
#  'mu justito ese penal eh',
#  'yo enamorado soy tal q así https://t.co/2koyOVejq8',
#  'Porque las palabras a veces son como flechas que una vez lanzadas no hay manera de detenerlas, por eso piensa muy bien antes de hablar, analiza lo que dirás para que tus palabras construyan y no destruyan a quien las recibe',
#  'Nunca soy yo',
#  '@jbsilva1090 @InformaCosmos Se puso su traje especial a prueba de ácidos y lo logro!!!',
#  '@ElReyDelMambo__ Que fregón 😏de todos colores y sabores. Se buscó la foto.',
#  '¿Chica, qué dices? https://t.co/CESEhvPWCX',
#  '@leoneltudo Soy cool tiraba JAJAJAJAJAJ',
#  'Absoluta masterclass de chiquitona lo de argentina sede del sub 20 eh',
#  'Nominación directa para Alma #SVGala5',
#  'Antes de emitir un Juicio sobre el Mechero, piensa que puede ser el próximo presidente!#GatilloFacil https://t.co/7i3AcKqOkz',
#  'Dónde me cuidan yo cuido el triple, y dónde me quieren yo quiero el quíntuple \U0001fa75',
#  'Les gusta mi corazón?🙈💗 https://t.co/vZrpiqHtbc',
#  'Que se vaya cuanto antes! #SVGala5 https://t.co/nQjEuSpWkL']

# %%
df_final.to_csv(f'{data_processed}/negatives.csv', index=False)
